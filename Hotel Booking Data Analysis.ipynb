# %% [markdown]
# # Business Problem

# %% [markdown]
# In recent year,City Hotel and Resort have seen high cancellatino rate.Each hotel is now dealing with number of issues as result,including fewer revenue and less then ideal room use.Consequentlly lowering cancellation rate in both hotel.Primary goal in order increase their efficientcy in generating revenue, and for us to busniess advice to address this problem.
#
# The analysis of hotel booking cancellation as well as other factor that have no bearing on their business and yearly revenue generation are the main topic of report.

# %% [markdown]
# # Assumption

# %% [raw]
#  1.No unusual occurrence between 2015and 2017 will have a substantial impact on the data used.
# 2.The information is still current and can be used to analyze a hotel's possible planes in an efficint manner
# 3.There are no unanticipated negative to the hotel employing and advised technique
# 4.The hotel are not currently any of the suggested solution.
# 5.The biggest factor affecting the effectiveness to earning income is booking cancellation
# 6.Chancellation result is vacant room for the booking length of time
# 7.Clients make hotel resarvation the same year they make cancellation

# %% [markdown]
# # Research Question

# %% [raw]
# 1.What are the variable that affected hotel reservation cancellation
# 2.How can we make hotel reservation cancellation better
# 3.How will hotel be assisted in making pricing and promotional decision

# %% [markdown]
# # Hypothesis

# %% [raw]
# 1.More cancellation occer when price and higher
# 2.When there is a longer wating list, customers tend to cancel more frequently
# 3.The majority of clients are coming from offline travel agents to make there reservation

# %% [markdown]
# # Importing library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # loding data set

# %%
df=pd.read_csv("hotel_booking.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# # Explarotary Data Analysis And Data Cleaning

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df["reservation_status_date"]=pd.to_datetime(df["reservation_status_date"])

# %%
df.describe(include="object")
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in df.describe(include="object").columns:
    print(col)
    print(df[col].unique())
    print("_"*60)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ____________________________________________________________
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ____________________________________________________________
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ____________________________________________________________
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(["agent","company"],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df=df[df['adr']<5000]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# # Data Analysis and Visulization

# %%
cancelled_per=df["is_canceled"].value_counts(normalize=True)
cancelled_per
# Out:
# is_canceled
# 0    0.628653
# 1    0.371347
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(5,4))
plt.bar(["Not_cancelled","Cancelled"],df["is_canceled"].value_counts())
plt.title("Reservation Status Count")
plt.show()

# %%
cancelled_per=df["is_canceled"].value_counts(normalize=True)*100
plt.figure(figsize=(5,4))
plt.bar(["Not_cancelled","Cancelled"],cancelled_per)
plt.title("Reservation Status Count")
plt.show()

# %% [markdown]
# The accompanying bar shows the percentage of reservation that are canceled and those that are not.It is obvious that there are still a significant number of reservation that have not been canceled.There aer 37% of clients who canceled there reservation,which has a signigicant impact on the hotel'S earning

# %%
plt.figure(figsize=(8,4))
ax=sns.countplot(x="hotel",hue='is_canceled',data=df)

plt.title("Reservation Status in different hotel")
plt.xlabel("hotel")
plt.ylabel("Number of reservation")
plt.legend(["Not Cancelled","Chancelled"])
plt.show()

# %% [markdown]
# In comparison to resort hotels,city hotels have more booking.It's possible that resort hotel are more expensive than those in city

# %%
resort_hotel=df[df["hotel"] == "Resort Hotel"]
resort_hotel["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
city_hotel=df[df['hotel']=='City Hotel']
city_hotel["is_canceled"].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.582918
# 1    0.417082
# Name: proportion, dtype: float64

# %%
resort_hotel=resort_hotel.groupby("reservation_status_date")[["adr"]].mean()
city_hotel=city_hotel.groupby("reservation_status_date")[["adr"]].mean()

# %%
plt.figure(figsize=(20,8))
plt.title("Avarage Daily Rate of Resort and City Hotel",fontsize=30)
plt.plot(resort_hotel.index,resort_hotel["adr"],label="Resort Hotel")
plt.plot(city_hotel.index,city_hotel["adr"],label="City Hotel")
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# The line graph avobe shows that,on certain days, the average daily rate for a city hotel isless then that of a resort hotel.nd on the other days,it is even less. It gose without saying that weekends and holidays may see a rice in resort hotel rates.

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(18,8))
ax=sns.countplot(x='month',hue='is_canceled',data=df,palette='bright')
plt.title=('Reservation Status Per Month')
plt.xlabel('month')
plt.ylabel('Number of Reservation')
plt.legend(['Not Cancelled','Cancelled'])
plt.show()

# %% [markdown]
# We have developed the grouped bar graph to analyze the months with the higest and lowest reservation levels according to reservation status.As can be seen, both the number of confirmed reservations and number of canceled reservation are largest in the month of August.Wheres January is the month with the most canceled reservations.

# %%
plt.figure(figsize=(15,8))
plt.title=('ADR Per Month')
sns.barplot(x='month', y='adr', data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())

#plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# This bar graph demonstrates that cancellations are most common when prices are greatest and are least common when they arelowest.Therfore,The cost of the accommodation is solely responsible for the cancellation.

# %%
cancelled_data=df[df["is_canceled"]==1]
top_10_country=cancelled_data["country"].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title=("Top 10 Country with reservation canceled")
plt.pie(top_10_country,autopct="%.2f",labels=top_10_country.index)
plt.show()

# %% [markdown]
# In this pie chart show that which country has the higest reservation canceled. The top country is Portugal with the higest number of cancellations.

# %%
df["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
df["market_segment"].value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        47.437698
# Offline TA/TO    20.319268
# Groups           16.658116
# Direct           10.469566
# Corporate         4.298679
# Complementary     0.617341
# Aviation          0.199332
# Name: proportion, dtype: float64

# %%
cancelled_data["market_segment"].value_counts()
# Out:
# market_segment
# Online TA        20738
# Groups           12097
# Offline TA/TO     8277
# Direct            1920
# Corporate          978
# Complementary       90
# Aviation            52
# Name: count, dtype: int64

# %%
cancelled_data["market_segment"].value_counts(normalize=True)*100
# Out:
# market_segment
# Online TA        46.969560
# Groups           27.398532
# Offline TA/TO    18.746603
# Direct            4.348614
# Corporate         2.215075
# Complementary     0.203841
# Aviation          0.117775
# Name: proportion, dtype: float64

# %% [markdown]
# Lets check the area from where guestts are visiting the hotels and making reservations.It is coming from Direct or Groups,Online or offline Travel Agents. Around 47% of the clients come from online agencies,whereas 20% come from offline and 16% come from group.Only 10% client book hotels directly by visiting them and making reservation.
# On the other hand, 46% client canceled ther reservation who reserve under Online travel agency, 27% client canceled ther reservation who reserve group. 18% client canceled ther reservation who reserve under Offline travel agency.Interstingly only 4% client canceled ther reservation who reserv ther hotel Directly

# %%
cancelled_df_adr=cancelled_data.groupby("reservation_status_date")[["adr"]].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values("reservation_status_date",inplace=True)

not_cancelled_data=df[df["is_canceled"]==0]
not_cancelled_df_adr=not_cancelled_data.groupby("reservation_status_date")[["adr"]].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values("reservation_status_date",inplace=True)

plt.figure(figsize=(20,6))
#plt.title("Avarage Daily Rate ",fontsize=30)
plt.plot(not_cancelled_df_adr["reservation_status_date"],not_cancelled_df_adr["adr"],label="not_canceled")
plt.plot(cancelled_df_adr["reservation_status_date"],cancelled_df_adr["adr"],label="canceled")
plt.legend()
plt.show()

# %%
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr["reservation_status_date"]>"2016")&(cancelled_df_adr["reservation_status_date"]<"2017-09")]
not_cancelled_df_adr=not_cancelled_df_adr[(not_cancelled_df_adr["reservation_status_date"]>"2016")&(not_cancelled_df_adr["reservation_status_date"]<"2017-09")]
plt.figure(figsize=(20,6))
#plt.title("Avarage Daily Rate ",fontsize=30)

plt.plot(not_cancelled_df_adr["reservation_status_date"],not_cancelled_df_adr["adr"],label="not_canceled")
plt.plot(cancelled_df_adr["reservation_status_date"],cancelled_df_adr["adr"],label="canceled")
plt.legend()
plt.show()

# %% [markdown]
# As seen in thegraph, reservations are canceled when the average daily rate is higher than when it is not canceled.It clearly proves all the above analysis,that the higher price leades to higher cancellation.

# %% [markdown]
# # Suggestion

# %% [markdown]
# 1=> Cancellation rates rice as the price does.In order to prevent to cancellations of reservation,hotels could work on their pricing strategies and try to lower the rates for specific hotels base on locations. They can also provide some discounts to the consumers

# %% [markdown]
# 2=> As the ratio of the cancellation are not cancellation of the resort hotel is higher in the resort hotel than city hotels.So the hotels should provide a resonable discount on the room pricees on weekends or on holiday

# %% [markdown]
# 3=>In the month of january,hotel can start campaigns or marketing with a reasonable amount to increase their revenue as the cancellation is the highest in this month

# %% [markdown]
# 4=>They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancallation rate
